# %%
import numpy as np
import sys
sys.path.append('../')
from utils import *
from  momentBasedReco import *
import matplotlib.pyplot as plt
import qutip as qt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 import sys
#       4 sys.path.append('../')
# ----> 5 from  momentBasedReco import *
#       6 import matplotlib.pyplot as plt
#       7 import qutip as qt
#
# File c:\Users\labranca\Documents\Projects\StateTomography\Data\..\momentBasedReco.py:4
#       2 from math import factorial, comb, sqrt
#       3 import sympy as sp
# ----> 4 import cvxpy as cvx
#       5 from joblib import Parallel, delayed
#       6 #
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\__init__.py:19
#       1 """
#       2 Copyright, the CVXPY authors
#       3
#    (...)
#      14 limitations under the License.
#      15 """
#      16 from cvxpy.version import (
#      17     version as __version__,
#      18 )  # cvxpy/version.py is auto-generated
# ---> 19 from cvxpy.atoms import *
#      20 from cvxpy.constraints import (
#      21     Constraint as Constraint,
#      22     Cone as Cone,
#    (...)
#      33     FiniteSet as FiniteSet,
#      34 )
#      35 from cvxpy.error import (
#      36     DCPError as DCPError,
#      37     DGPError as DGPError,
#    (...)
#      42     warnings_enabled as warnings_enabled,
#      43 )
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\atoms\__init__.py:17
#       1 """
#       2 Copyright 2013 Steven Diamond
#       3
#    (...)
#      14 limitations under the License.
#      15 """
# ---> 17 from cvxpy.atoms.affine.binary_operators import (matmul, multiply,
#      18                                                  vdot, scalar_product, outer,)
#      19 from cvxpy.atoms.affine.bmat import bmat
#      20 from cvxpy.atoms.affine.conj import conj
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\atoms\affine\binary_operators.py:28
#      26 import cvxpy.lin_ops.lin_utils as lu
#      27 import cvxpy.utilities as u
# ---> 28 from cvxpy.atoms.affine.add_expr import AddExpression
#      29 from cvxpy.atoms.affine.affine_atom import AffAtom
#      30 from cvxpy.atoms.affine.conj import conj
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:23
#      21 import cvxpy.lin_ops.lin_utils as lu
#      22 import cvxpy.utilities as u
# ---> 23 from cvxpy.atoms.affine.affine_atom import AffAtom
#      24 from cvxpy.constraints.constraint import Constraint
#      25 from cvxpy.expressions.expression import Expression
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\atoms\affine\affine_atom.py:24
#      22 import cvxpy.utilities as u
#      23 from cvxpy.atoms.atom import Atom
# ---> 24 from cvxpy.cvxcore.python import canonInterface
#      25 from cvxpy.expressions.constants import Constant
#      26 from cvxpy.utilities import performance_utils as perf
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\cvxcore\python\canonInterface.py:25
#      23 import cvxpy.settings as s
#      24 from cvxpy.lin_ops import lin_op as lo
# ---> 25 from cvxpy.lin_ops.canon_backend import CanonBackend
#      28 def get_parameter_vector(param_size,
#      29                          param_id_to_col,
#      30                          param_id_to_size,
#      31                          param_id_to_value_fn,
#      32                          zero_offset: bool = False):
#      33     """Returns a flattened parameter vector
#      34
#      35     The flattened vector includes a constant offset (i.e, a 1).
#    (...)
#      48         A flattened NumPy array of parameter values, of length param_size + 1
#      49     """
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\cvxpy\lin_ops\canon_backend.py:25
#      23 import numpy as np
#      24 import scipy.sparse as sp
# ---> 25 from scipy.signal import convolve
#      27 import cvxpy.settings as s
#      28 from cvxpy.lin_ops import LinOp
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\scipy\signal\__init__.py:311
#     309 from ._spectral_py import *
#     310 from ._short_time_fft import *
# --> 311 from ._peak_finding import *
#     312 from ._czt import *
#     313 from .windows import get_window  # keep this one in signal namespace
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\scipy\signal\_peak_finding.py:8
#       5 import numpy as np
#       7 from scipy.signal._wavelets import _cwt, _ricker
# ----> 8 from scipy.stats import scoreatpercentile
#      10 from ._peak_finding_utils import (
#      11     _local_maxima_1d,
#      12     _select_by_peak_distance,
#      13     _peak_prominences,
#      14     _peak_widths
#      15 )
#      18 __all__ = ['argrelmin', 'argrelmax', 'argrelextrema', 'peak_prominences',
#      19            'peak_widths', 'find_peaks', 'find_peaks_cwt']
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\scipy\stats\__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\scipy\stats\_stats_py.py:59
#      56 from ._stats import _kendall_dis, _toint64, _weightedrankedtau
#      58 from dataclasses import dataclass, field
# ---> 59 from ._hypotests import _all_partitions
#      60 from ._stats_pythran import _compute_outer_prob_inside_method
#      61 from ._resampling import (MonteCarloMethod, PermutationMethod, BootstrapMethod,
#      62                           monte_carlo_test, permutation_test, bootstrap,
#      63                           _batch_generator)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1190, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
data = matlab2dict('QuadratureDistribution_Digitizer/16-Feb-2024/20240216_132619_QuadratureDistributions_ModeMatching.mat')
phase_corr = np.pi/4

N0 = 8.664

scale = np.sqrt(np.var(np.concatenate([data['I1_vacuum'], data['Q1_vacuum']])) / (1/2 + N0/2))
data['I1_vacuum'] = data['I1_vacuum']/scale
data['Q1_vacuum'] = data['Q1_vacuum']/scale
data['I1_pi'] = data['I1_pi']/scale
data['Q1_pi'] = data['Q1_pi']/scale
data['I1_pi_half'] = data['I1_pi_half']/scale
data['Q1_pi_half'] = data['Q1_pi_half']/scale


S_vac = (data['I1_vacuum'] + 1j*data['Q1_vacuum'])*np.exp(1j*phase_corr)
S_pi = (data['I1_pi'] + 1j*data['Q1_pi'])*np.exp(1j*phase_corr)
S_pi_half = (data['I1_pi_half'] + 1j*data['Q1_pi_half'])*np.exp(1j*phase_corr)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(S_vac.real, S_vac.imag, label='$|0\\rangle$', color='black', s=1)
ax.scatter(S_pi.real, S_pi.imag, label='$|1\\rangle$', color='red', s=1)
ax.scatter(S_pi_half.real, S_pi_half.imag, label='$|0\\rangle + |1\\rangle$', color='blue', s=1)
ax.set_xlim([-2*N0, 2*N0])
ax.set_ylim([-2*N0, 2*N0])
ax.set_aspect('equal')
ax.legend(loc='upper right')

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.hist(S_vac.real, 100, label='$|0\\rangle$',edgecolor='black', facecolor=None, histtype='step')
ax.hist(S_pi.real, 100, label='$|1\\rangle$', edgecolor='red', facecolor=None, histtype='step')
ax.hist(S_pi_half.real, 100, label='$|0\\rangle + |1\\rangle$', edgecolor='blue', facecolor=None, histtype='step')

ax.set_xlim([-2*N0, 2*N0])

ax.legend(loc='best')

# %% [markdown]
# # Moments based reconstruction

# %%
# Compute measured moments up to order 2
max_order = 3

# Compute noise moments
vac_moments, vac_moments_unc  = calculate_moments_uncertainty_vectorized(S_vac, max_order)

# Compute measured moments up to order 2
pi_moments, pi_moments_unc  = calculate_moments_uncertainty_vectorized(S_pi, max_order)
pi_half_moments, pi_half_moments_unc  = calculate_moments_uncertainty_vectorized(S_pi_half, max_order)

# %%
# Compute signal moments with vectorized MonteCarlo
MCsamples = 10000000
gnd_moments, gnd_moments_unc  = extract_a_moments_uncertainty_vectorized(vac_moments, vac_moments_unc, vac_moments, max_order, MCsamples)
sig_pi_moments, sig_pi_moments_unc  = extract_a_moments_uncertainty_vectorized(pi_moments, pi_moments_unc, vac_moments, max_order, MCsamples) 
sig_pi_half_moments, sig_pi_half_moments_unc  = extract_a_moments_uncertainty_vectorized(pi_half_moments, pi_half_moments_unc, vac_moments, max_order, MCsamples)

# %%
sig_pi_moments
# Out:
# array([[ 1.00000000e+00,  9.57454414e-02,  1.56342908e-02,
#          3.19886043e-03],
#        [ 9.73455615e-02,  1.01707927e+00, -5.04776375e-02,
#          5.60438017e-02],
#        [ 1.34242552e-02, -7.83810954e-02, -1.00204329e-01,
#         -1.33255977e+00],
#        [ 3.10659646e-02, -1.18607682e-01,  2.36840618e-01,
#          2.49582860e+01]])

# %%
d = 20

#Maximum Likelihood reconstruction
gnd_rec_MBR = moments_to_density_matrix_ml(gnd_moments, gnd_moments_unc, d)
sig_pi_rec_MBR = moments_to_density_matrix_ml(sig_pi_moments, sig_pi_moments_unc, d)
sig_pi_half_rec_MBR = moments_to_density_matrix_ml(sig_pi_half_moments, sig_pi_half_moments_unc, d)

# %% [markdown]
# ## Plots

# %%
fig, ax = plt.subplots()
fig.suptitle('Vacuum state - MBR')
cm = ax.pcolormesh(np.abs(gnd_rec_MBR), cmap='seismic', vmin=0, vmax=1)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
ax.text(1,d-2,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(gnd_rec_MBR), qt.fock_dm(d,0))**2:.2f}%', fontsize=15, color='white')
ax.set_aspect('equal', adjustable='box')

fig, ax = plt.subplots()
fig.suptitle('Fock state $|1 \\rangle$ - MBR')
cm = ax.pcolormesh(np.abs(sig_pi_rec_MBR), cmap='seismic', vmin=0, vmax=1)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
ax.text(1,d-2,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_rec_MBR), qt.fock_dm(d,1))**2:.2f}%', fontsize=15, color='white')
ax.set_aspect('equal', adjustable='box')


fig, ax = plt.subplots()
fig.suptitle('Fock state $|0 \\rangle + |1 \\rangle$ - MBR')
cm = ax.pcolormesh(np.abs(sig_pi_half_rec_MBR), cmap='seismic', vmin=0, vmax=1)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
st = np.sqrt(1/2) * (qt.basis(d,1) +  qt.basis(d,0))
ax.text(1,d-2,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_half_rec_MBR), st*st.dag())**2:.2f}%', fontsize=15, color='white')
ax.set_aspect('equal', adjustable='box')

# %%
x_s, p_s = np.linspace(-3,3,301), np.linspace(-3,3,301)

fig, ax = plt.subplots()
fig.suptitle('Vacuum state - MBR')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(gnd_rec_MBR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(gnd_rec_MBR), qt.fock_dm(d,0))**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')

fig, ax = plt.subplots()
fig.suptitle('Fock state $|1 \\rangle$ - MBR')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(sig_pi_rec_MBR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_rec_MBR), qt.fock_dm(d,1))**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')


fig, ax = plt.subplots()
fig.suptitle('Fock state $|0 \\rangle + |1 \\rangle$ - MBR')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(sig_pi_half_rec_MBR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
st = np.sqrt(1/2) * (qt.basis(d,1) +  qt.basis(d,0))
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_half_rec_MBR), st*st.dag())**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')

# %%
print('g2 thermal:', g2_from_moments_with_uncertainty(vac_moments, vac_moments_unc)[0], ' +/- ', g2_from_moments_with_uncertainty(vac_moments, vac_moments_unc)[1])
print('g2 pi:', g2_from_moments_with_uncertainty(sig_pi_moments, sig_pi_moments_unc)[0], ' +/- ', g2_from_moments_with_uncertainty(sig_pi_moments, sig_pi_moments_unc)[1])
print('g2 pi half:', g2_from_moments_with_uncertainty(sig_pi_half_moments, sig_pi_half_moments_unc)[0], ' +/- ', g2_from_moments_with_uncertainty(sig_pi_half_moments, sig_pi_half_moments_unc)[1])

print('g2 pi:', g2_from_density_matrix(sig_pi_rec_MBR))
print('g2 pi half:', g2_from_density_matrix(sig_pi_half_rec_MBR))
# Out:
# g2 thermal: 2.00451742296779  +/-  6.03361952511107
# g2 pi: -0.09686722932312394  +/-  625.8638072100912
# g2 pi half: 0.8181169378330648  +/-  2201.673988919262
# g2 pi: 0.06489743681799096
# g2 pi half: 1.2639534616904227

# %% [markdown]
# # $R \rho R$ reconstruction

# %%
from RmatrixBasedReco import *
d = 90
nbins = 31

tol = 0.1

counts, alphas = prepare_histograms(np.squeeze(S_vac), nbins)
povm_list = [coherent_state_povm(alpha, d) for alpha in alphas]
therm_rec_RrhorR, therm_lik_RrhorR, therm_eig_RrhorR = rhorho_reconstruction(povm_list, counts.flatten(), max_iter=100000, useG=True, dilution=1e-1, tol=tol, improvement_tol=1e-10, patience=100, track_likelihood=True)

fig, ax = plt.subplots(2, 1, figsize=(8, 7))
fig.suptitle('Detector State Reconstruction')
ax[0].plot(np.arange(1, len(therm_lik_RrhorR)+1), therm_lik_RrhorR)
ax[0].set_title('Likelihood')
ax[0].set_xscale('log')
ax[0].grid()

ax[1].plot(np.arange(1, len(therm_eig_RrhorR)+1), np.abs(therm_eig_RrhorR)-1)
ax[1].axhline(tol*np.sqrt((len(povm_list)**2 - 1) / 2) / np.sum(counts), color='black', linestyle='--', label='Convergence Threshold')
ax[1].set_title('|R Maximum Eigenvalue - 1|')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].grid()
ax[1].legend()  
fig.tight_layout()
# Out:
# Iteration: 118/100000 | Percentage: 0.05% | |maxEig(R)-1|: 6.15e-02 > 3.24e-05 | Log-Likelihood: -4.4235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       7 counts, alphas = prepare_histograms(np.squeeze(S_vac), nbins)
#       8 povm_list = [coherent_state_povm(alpha, d) for alpha in alphas]
# ----> 9 therm_rec_RrhorR, therm_lik_RrhorR, therm_eig_RrhorR = rhorho_reconstruction(povm_list, counts.flatten(), max_iter=100000, useG=True, dilution=1e-1, tol=tol, improvement_tol=1e-10, patience=100, track_likelihood=True)
#      11 fig, ax = plt.subplots(2, 1, figsize=(8, 7))
#      12 fig.suptitle('Detector State Reconstruction')
#
# File c:\Users\labranca\Documents\Projects\StateTomography\Data\..\RmatrixBasedReco.py:110, in rhorho_reconstruction(povm_list, counts, init_rho, max_iter, tol, useG, dilution, improvement_tol, patience, track_likelihood)
#     105 r_eigenvalue_history = [] if track_likelihood else None
#     107 for iteration in range(max_iter):
#     108
#     109     # Compute predicted probabilities p_i = Tr(ρ Π_i)
# --> 110     p = np.array([np.trace(rho @ Pi).real for Pi in povm_list])
#     111     # Avoid division by zero – add a tiny number if necessary.
#     112     p = np.maximum(p, 1e-12)
#
# File c:\Users\labranca\Documents\EnvPython\quantumEnv\Lib\site-packages\numpy\_core\fromnumeric.py:1826, in _trace_dispatcher(a, offset, axis1, axis2, dtype, out)
#    1822     else:
#    1823         return asanyarray(a).diagonal(offset=offset, axis1=axis1, axis2=axis2)
# -> 1826 def _trace_dispatcher(
#    1827         a, offset=None, axis1=None, axis2=None, dtype=None, out=None):
#    1828     return (a, out)
#    1831 @array_function_dispatch(_trace_dispatcher)
#    1832 def trace(a, offset=0, axis1=0, axis2=1, dtype=None, out=None):
#
# KeyboardInterrupt:

# %%
tol = 1e-2


counts, alphas = prepare_histograms(np.squeeze(S_pi), nbins)
povm_list = [displaced_thermal_povm(alpha, N0, d) for alpha in alphas]
sig_pi_rec_RrhoR, sig_pi_lik_RrhoR, sig_pi_eig_RrhoR = rhorho_reconstruction(povm_list, counts.flatten(), max_iter=50000, useG=True, dilution=None, tol=tol, improvement_tol=1e-10, patience=1000, track_likelihood=True)
fig, ax = plt.subplots(2, 1, figsize=(8, 7))
fig.suptitle('Signal State Reconstruction')
ax[0].plot(np.arange(1, len(sig_pi_lik_RrhoR)+1), sig_pi_lik_RrhoR)
ax[0].set_title('Likelihood')
ax[0].set_xscale('log')
ax[0].grid()

ax[1].plot(np.arange(1, len(sig_pi_eig_RrhoR)+1), np.abs(sig_pi_eig_RrhoR)-1)
ax[1].axhline(tol*np.sqrt((len(povm_list)**2 - 1) / 2) / np.sum(counts), color='black', linestyle='--', label='Convergence Threshold')
ax[1].set_title('|R Maximum Eigenvalue - 1|')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].grid()
ax[1].legend()  
fig.tight_layout()
# Out:
# Iteration: 31663/50000 | Percentage: 32.70% | |maxEig(R)-1|: 9.90e-06 > 3.24e-06 | Log-Likelihood: -4.5231
# No significant improvement in the last 1000 iterations. Stopping iterations.

# %%
tol = 1e-2


counts, alphas = prepare_histograms(np.squeeze(S_pi_half), nbins)
povm_list = [displaced_thermal_povm(alpha, N0, d) for alpha in alphas]
sig_pi_half_rec_RrhoR, sig_pi_half_lik_RrhoR, sig_pi_half_eig_RrhoR = rhorho_reconstruction(povm_list, counts.flatten(), max_iter=50000, useG=True, dilution=None, tol=tol, improvement_tol=1e-10 , patience=1000, track_likelihood=True)
fig, ax = plt.subplots(2, 1, figsize=(8, 7))
fig.suptitle('Signal State Reconstruction')
ax[0].plot(np.arange(1, len(sig_pi_half_lik_RrhoR)+1), sig_pi_half_lik_RrhoR)
ax[0].set_title('Likelihood')
ax[0].set_xscale('log')
ax[0].grid()

ax[1].plot(np.arange(1, len(sig_pi_half_eig_RrhoR)+1), np.abs(sig_pi_half_eig_RrhoR)-1)
ax[1].axhline(tol*np.sqrt((len(povm_list)**2 - 1) / 2) / np.sum(counts), color='black', linestyle='--', label='Convergence Threshold')
ax[1].set_title('|R Maximum Eigenvalue - 1|')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].grid()
ax[1].legend()  
fig.tight_layout()
# Out:
# Iteration: 16281/50000 | Percentage: 10.56% | |maxEig(R)-1|: 3.06e-05 > 3.24e-06 | Log-Likelihood: -4.4522
# No significant improvement in the last 1000 iterations. Stopping iterations.

# %% [markdown]
# ## Plots

# %%
fig, ax = plt.subplots()
fig.suptitle('Detector thermal state')
ax.scatter(np.arange(0,d),np.diagonal(np.abs(therm_rec_RrhorR)), label='$R \\rho R$')
ax.plot(np.arange(0,d), np.diagonal(np.abs(qt.thermal_dm(d, N0).full())), color='red', label='Theoretical')
ax.set_xlabel('Density matrix index $i$', fontsize=15)
ax.set_ylabel('$\\langle i|\\rho|i \\rangle$', fontsize=15)
ax.grid()
ax.legend()


fig, ax = plt.subplots()
fig.suptitle('Detector thermal state')
cb = ax.pcolormesh(np.abs(therm_rec_RrhorR))
fig.colorbar(cb)
ax.set_xlabel('Density matrix index $i$', fontsize=15)
ax.set_ylabel('Density matrix index $j$', fontsize=15)
ax.set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 fig, ax = plt.subplots()
#       2 fig.suptitle('Detector thermal state')
# ----> 3 ax.scatter(np.arange(0,d),np.diagonal(np.abs(therm_rec_RrhorR)), label='$R \\rho R$')
#       4 ax.plot(np.arange(0,d), np.diagonal(np.abs(qt.thermal_dm(d, N0).full())), color='red', label='Theoretical')
#       5 ax.set_xlabel('Density matrix index $i$', fontsize=15)
#
# NameError: name 'therm_rec_RrhorR' is not defined

# %%
x_s, p_s = np.linspace(-3,3,301), np.linspace(-3,3,301)

fig, ax = plt.subplots()
fig.suptitle('Detector thermal state - $R \\rho R$')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(therm_rec_RrhorR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(therm_rec_RrhorR), qt.thermal_dm(d,N0))**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')

fig, ax = plt.subplots()
fig.suptitle('Fock state $|1 \\rangle$ - $R \\rho R$')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(sig_pi_eig_RrhoR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_eig_RrhoR), qt.fock_dm(d,1))**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')


fig, ax = plt.subplots()
fig.suptitle('Fock state $|1 \\rangle$ with inefficiency - $R \\rho R$')
cm = ax.pcolormesh(x_s, p_s, qt.wigner(qt.Qobj(sig_pi_half_rec_RrhoR), x_s, p_s), cmap='seismic', vmax=2/np.pi, vmin=-2/np.pi)
cb = plt.colorbar(cm, ax=ax)
cb.ax.tick_params('both', labelsize=18)
cb.set_ticks([-2/np.pi, 0, 2/np.pi])
cb.set_ticklabels(['$-\\frac{2}{\\pi}$', '0', '$\\frac{2}{\\pi}$'])
ax.text(-2.5,2.5,'$\\mathcal{F}$ = ' + f'{100*qt.fidelity(qt.Qobj(sig_pi_half_rec_RrhoR), qt.fock_dm(d,1))**2:.2f}%', fontsize=15)
ax.set_aspect('equal', adjustable='box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_s, p_s = np.linspace(-3,3,301), np.linspace(-3,3,301)
#       3 fig, ax = plt.subplots()
#       4 fig.suptitle('Detector thermal state - $R \\rho R$')
#
# NameError: name 'np' is not defined
